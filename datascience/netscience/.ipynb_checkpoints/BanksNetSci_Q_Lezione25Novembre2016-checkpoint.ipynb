# %%
#NETWORKX / JSON / DATAFRAME / ADJMX / METRICS+SCATTER / VIZ+GEPHI

# %%
# %pylab inline
import numpy as np
import pandas as pd
import networkx as nx
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # NetworkX

# %%
#create
demo = nx.Graph()  # creo un grapho vuoto; in una connessione non orientata, 
# l'arco AB è uguale a quello BA (sovrascrive la precedente connessione)

# demo = nx.DiGraph()  serve per fare delle connessioni orientate

consonants = list(set("bcdfghjklmnpqrstvwxyz"))
vowels = list(set("aeiou"))

#add nodes
for c in consonants:
    demo.add_node(c)   # demo = nome grapho; add_node = metodo
for v in vowels:
    demo.add_node(v)
    
#add random edges   #con il metodo add_edge aggiungo ARCHI
for i in range(50):  # aggiungo delle connessioni tra consonanti in modo random
    demo.add_edge(numpy.random.choice(consonants),numpy.random.choice(consonants))
    
    # provare con meno nodi: range (5), per es
    
for i in range(100):   # aggiungo delle connessioni tra vocali in modo random
    demo.add_edge(numpy.random.choice(vowels),numpy.random.choice(vowels))

# nodo center= degree molto basso, betweeness molto alta; tutti i cammini minimi passano da qui    
demo.add_edge('a', 'center')  
demo.add_edge('q', 'center')  
   
    
# draw
nx.draw(demo, with_labels=True, node_color=['red' if i in set('aeiou') else 'cyan' for i in demo.nodes_iter()])
# metodo nodes_iter = iteratore di nodi

# %%
print 'connected components',[cc for cc in nx.connected_components(demo)]
print

print 'degrees',np.array(nx.degree(demo))
print
# chiavi = label dei nodi; i valori sono i degree di ogni nodo
# degree = archi entranti, archi uscenti per nodo

print 'clustering_coefficients',np.array(nx.clustering(demo))
print

print 'diameter_vowels:',nx.diameter(demo.subgraph(vowels)),'- dimameter_consonant:',nx.diameter(demo.subgraph(consonants))

# subgraph:prendi solo il sottographo delle vocali, così isolo il sottographo rosso
# diametro: massimo numero di passi per andare da un punto all'altro all'interno del grapho
# Out:
# connected components [set(['d', 'a', 'c', 'b', 'e', 'center', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])]
#
# degrees {'d': 7, 'a': 7, 'c': 7, 'b': 3, 'e': 6, 'center': 2, 'g': 7, 'f': 2, 'i': 6, 'h': 3, 'k': 1, 'j': 9, 'm': 1, 'l': 5, 'o': 6, 'n': 1, 'q': 2, 'p': 6, 's': 6, 'r': 1, 'u': 6, 't': 5, 'w': 5, 'v': 6, 'y': 4, 'x': 2, 'z': 4}
#
# clustering_coefficients {'d': 0.2857142857142857, 'a': 0.6, 'c': 0.19047619047619047, 'b': 0.0, 'e': 1.0, 'center': 0.0, 'g': 0.14285714285714285, 'f': 0.0, 'i': 1.0, 'h': 0.0, 'k': 0.0, 'j': 0.25, 'm': 0.0, 'l': 0.3, 'o': 1.0, 'n': 0.0, 'q': 0.0, 'p': 0.4, 's': 0.4666666666666667, 'r': 0.0, 'u': 1.0, 't': 0.5, 'w': 0.1, 'v': 0.2, 'y': 0.3333333333333333, 'x': 0.0, 'z': 0.3333333333333333}
#
# diameter_vowels: 1 - dimameter_consonant: 4

# %% [markdown]
# # Data Import

# %%
#get data, as jsons, from http://bank.top-ix.org/banks

# %%
import urllib2
import json
request = urllib2.urlopen('http://bank.top-ix.org/banks')
data = json.loads(request.read())
#connect
index = [(entry['BANK_ID'],entry['BANK']) for entry in data['data']]
# qui ho l'indice = tutte le banche

payload = json.loads(urllib2.urlopen('http://bank.top-ix.org/data/'+str(index[0][0])).read())
# qui invece copio su google l'indirizzo più un numero (che è la banca) e trovo i dati di quella banca
# [0] [0]: prendo la prima banca e la prima riga
# ad esempio, per la prima banca scrivo: http://bank.top-ix.org/data/0

#init dataframe
fields = np.array(payload['data'][0].keys())
data = pd.DataFrame({i:[] for i in range(6)})
data.columns = fields
data
# Out:
# Empty DataFrame
# Columns: [GDP_2012_EURO, BANK_COUNTRY, MILLIONS_EUROS, EXPOSURE_COUNTRY, COUNTRY_EXPOSURE, BANK]
# Index: []

# %%
index
# Out:
# [(0, u'Erste Group Bank AG'),
#  (1, u'Raiffeisen Zentralbank \xd6sterreich AG'),
#  (2, u'KBC BANK'),
#  (3, u'CYPRUS POPULAR BANK PUBLIC CO LTD'),
#  (4, u'BANK OF CYPRUS PUBLIC CO LTD'),
#  (5, u'DEUTSCHE BANK AG'),
#  (6, u'COMMERZBANK AG'),
#  (7, u'Landesbank Baden-W\xfcrttemberg'),
#  (8, u'DZ BANK AG Dt. Zentral-Genossenschaftsbank'),
#  (9, u'Bayerische Landesbank'),
#  (10, u'Norddeutsche Landesbank -GZ'),
#  (11, u'Hypo Real Estate Holding AG, M\xfcnchen'),
#  (12, u'HSH Nordbank AG, Hamburg'),
#  (13, u'Landesbank Hessen-Th\xfcringen GZ, Frankfurt'),
#  (14, u'Landesbank Berlin AG'),
#  (15, u'DekaBank Deutsche Girozentrale, Frankfurt'),
#  (16, u'WGZ BANK AG Westdt. Geno. Zentralbk, Ddf'),
#  (17, u'DANSKE BANK'),
#  (18, u'Jyske Bank'),
#  (19, u'Sydbank'),
#  (20, u'Nykredit'),
#  (21, u'BANCO SANTANDER S.A.'),
#  (22, u'BANCO BILBAO VIZCAYA ARGENTARIA S.A. (BBVA)'),
#  (23, u'CAJA DE AHORROS Y PENSIONES DE BARCELONA'),
#  (24, u'BANCO POPULAR ESPA\xd1OL, S.A.'),
#  (25, u'OP-Pohjola Group'),
#  (26, u'BNP PARIBAS'),
#  (27, u'CREDIT AGRICOLE'),
#  (28, u'BPCE'),
#  (29, u'SOCIETE GENERALE'),
#  (30, u'ROYAL BANK OF SCOTLAND GROUP plc'),
#  (31, u'HSBC HOLDINGS plc'),
#  (32, u'BARCLAYS plc'),
#  (33, u'LLOYDS BANKING GROUP plc'),
#  (34, u'OTP BANK NYRT.'),
#  (35, u'ALLIED IRISH BANKS PLC'),
#  (36, u'BANK OF IRELAND'),
#  (37, u'IRISH LIFE AND PERMANENT'),
#  (38, u'INTESA SANPAOLO S.p.A'),
#  (39, u'UNICREDIT S.p.A'),
#  (40, u'BANCA MONTE DEI PASCHI DI SIENA S.p.A'),
#  (41, u'BANCO POPOLARE - S.C.'),
#  (42, u'UNIONE DI BANCHE ITALIANE SCPA (UBI BANCA)'),
#  (43, u"BANQUE ET CAISSE D'EPARGNE DE L'ETAT"),
#  (44, u'BANK OF VALLETTA (BOV)'),
#  (45, u'ING BANK NV'),
#  (46, u'RABOBANK NEDERLAND'),
#  (47, u'ABN AMRO BANK NV'),
#  (48, u'SNS BANK NV'),
#  (49, u'DnB NOR Bank ASA'),
#  (50, u'POWSZECHNA KASA OSZCZ?DNO?CI BANK POLSKI S.A. (PKO BANK POLSKI)'),
#  (51, u'CAIXA GERAL DE DEP\xd3SITOS, SA'),
#  (52, u'BANCO COMERCIAL PORTUGU\xcaS, SA (BCP OR MILLENNIUM BCP)'),
#  (53, u'ESP\xcdRITO SANTO FINANCIAL GROUP, SA (ESFG)'),
#  (54, u'Banco BPI, SA'),
#  (55, u'Nordea Bank AB (publ)'),
#  (56, u'Skandinaviska Enskilda Banken AB (publ) (SEB)'),
#  (57, u'Svenska Handelsbanken AB (publ)'),
#  (58, u'Swedbank AB (publ)'),
#  (59, u'NOVA LJUBLJANSKA BANKA D.D. (NLB d.d.)'),
#  (60, u'NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)')]

# %%
payload
# Out:
# {u'bank': {u'BANK': u'Erste Group Bank AG', u'BANK_ID': 0},
#  u'data': [{u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'28.27',
#    u'EXPOSURE_COUNTRY': u'Austria',
#    u'GDP_2012_EURO': u'309,900.90',
#    u'MILLIONS_EUROS': u'9,150.23'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.29',
#    u'EXPOSURE_COUNTRY': u'Belgium',
#    u'GDP_2012_EURO': u'376,840.00',
#    u'MILLIONS_EUROS': u'92.73'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.01',
#    u'EXPOSURE_COUNTRY': u'Bulgaria',
#    u'GDP_2012_EURO': u'39,667.70',
#    u'MILLIONS_EUROS': u'1.76'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Cyprus',
#    u'GDP_2012_EURO': u'17,886.80',
#    u'MILLIONS_EUROS': u'0.00'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'29.84',
#    u'EXPOSURE_COUNTRY': u'Czech Republic',
#    u'GDP_2012_EURO': u'152,828.00',
#    u'MILLIONS_EUROS': u'9,659.61'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Denmark',
#    u'GDP_2012_EURO': u'244,063.70',
#    u'MILLIONS_EUROS': u'0.02'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Estonia',
#    u'GDP_2012_EURO': u'16,998.20',
#    u'MILLIONS_EUROS': u'0.00'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.24',
#    u'EXPOSURE_COUNTRY': u'Finland',
#    u'GDP_2012_EURO': u'194,469.00',
#    u'MILLIONS_EUROS': u'78.68'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.33',
#    u'EXPOSURE_COUNTRY': u'France',
#    u'GDP_2012_EURO': u'2,029,877.40',
#    u'MILLIONS_EUROS': u'106.22'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'2.73',
#    u'EXPOSURE_COUNTRY': u'Germany',
#    u'GDP_2012_EURO': u'2,643,900.00',
#    u'MILLIONS_EUROS': u'883.61'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Greece',
#    u'GDP_2012_EURO': u'193,749.00',
#    u'MILLIONS_EUROS': u'0.76'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'5.00',
#    u'EXPOSURE_COUNTRY': u'Hungary',
#    u'GDP_2012_EURO': u'97,756.30',
#    u'MILLIONS_EUROS': u'1,618.29'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Iceland',
#    u'GDP_2012_EURO': u'10,627.50',
#    u'MILLIONS_EUROS': u'0.00'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.12',
#    u'EXPOSURE_COUNTRY': u'Ireland',
#    u'GDP_2012_EURO': u'163,595.40',
#    u'MILLIONS_EUROS': u'38.93'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.25',
#    u'EXPOSURE_COUNTRY': u'Italy',
#    u'GDP_2012_EURO': u'1,565,916.10',
#    u'MILLIONS_EUROS': u'79.96'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.01',
#    u'EXPOSURE_COUNTRY': u'Latvia',
#    u'GDP_2012_EURO': u'22,258.00',
#    u'MILLIONS_EUROS': u'4.78'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Liechtenstein',
#    u'GDP_2012_EURO': u'3,860.50',
#    u'MILLIONS_EUROS': u'0.00'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.02',
#    u'EXPOSURE_COUNTRY': u'Lithuania',
#    u'GDP_2012_EURO': u'32,781.80',
#    u'MILLIONS_EUROS': u'6.95'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.07',
#    u'EXPOSURE_COUNTRY': u'Luxembourg',
#    u'GDP_2012_EURO': u'44,218.80',
#    u'MILLIONS_EUROS': u'22.56'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'Malta',
#    u'GDP_2012_EURO': u'6,755.90',
#    u'MILLIONS_EUROS': u'0.73'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.19',
#    u'EXPOSURE_COUNTRY': u'Netherlands',
#    u'GDP_2012_EURO': u'601,086.00',
#    u'MILLIONS_EUROS': u'62.85'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.03',
#    u'EXPOSURE_COUNTRY': u'Norway',
#    u'GDP_2012_EURO': u'390,008.70',
#    u'MILLIONS_EUROS': u'8.48'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'2.06',
#    u'EXPOSURE_COUNTRY': u'Poland',
#    u'GDP_2012_EURO': u'381,361.40',
#    u'MILLIONS_EUROS': u'667.40'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.01',
#    u'EXPOSURE_COUNTRY': u'Portugal',
#    u'GDP_2012_EURO': u'165,386.60',
#    u'MILLIONS_EUROS': u'3.22'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'12.28',
#    u'EXPOSURE_COUNTRY': u'Romania',
#    u'GDP_2012_EURO': u'131,739.60',
#    u'MILLIONS_EUROS': u'3,976.74'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'16.91',
#    u'EXPOSURE_COUNTRY': u'Slovakia',
#    u'GDP_2012_EURO': u'71,463.00',
#    u'MILLIONS_EUROS': u'5,473.68'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'1.18',
#    u'EXPOSURE_COUNTRY': u'Slovenia',
#    u'GDP_2012_EURO': u'35,466.30',
#    u'MILLIONS_EUROS': u'383.17'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.14',
#    u'EXPOSURE_COUNTRY': u'Spain',
#    u'GDP_2012_EURO': u'1,048,490.60',
#    u'MILLIONS_EUROS': u'45.38'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.01',
#    u'EXPOSURE_COUNTRY': u'Sweden',
#    u'GDP_2012_EURO': u'408,467.20',
#    u'MILLIONS_EUROS': u'4.33'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'0.00',
#    u'EXPOSURE_COUNTRY': u'United Kingdom',
#    u'GDP_2012_EURO': u'1,898,520.10',
#    u'MILLIONS_EUROS': u'1.44'},
#   {u'BANK': u'Erste Group Bank AG',
#    u'BANK_COUNTRY': u'Austria',
#    u'COUNTRY_EXPOSURE': u'100.00',
#    u'EXPOSURE_COUNTRY': u'TOTAL EEA 30',
#    u'GDP_2012_EURO': u'',
#    u'MILLIONS_EUROS': u'32,372.51'}]}

# %%
#EX_1: fill in

#download data for each bank
for eind,entry in enumerate(index):
    payload = json.loads(urllib2.urlopen('http://bank.top-ix.org/data/'+str(entry[0])).read()) 
    print 'loaded',eind+1,'of',len(index),':',payload['bank']['BANK']
    for element in payload['data']:
# loaded 52 of 61 : CAIXA GERAL DE DEPÓSITOS, SA
# loaded 53 of 61 : BANCO COMERCIAL PORTUGUÊS, SA (BCP OR MILLENNIUM BCP)
# loaded 54 of 61 : ESPÍRITO SANTO FINANCIAL GROUP, SA (ESFG)
# loaded 55 of 61 : Banco BPI, SA
# loaded 56 of 61 : Nordea Bank AB (publ)
# loaded 57 of 61 : Skandinaviska Enskilda Banken AB (publ) (SEB)
# loaded 58 of 61 : Svenska Handelsbanken AB (publ)
# loaded 59 of 61 : Swedbank AB (publ)
# loaded 60 of 61 : NOVA LJUBLJANSKA BANKA D.D. (NLB d.d.)
# loaded 61 of 61 : NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)

# %%
data
# Out:
#      GDP_2012_EURO BANK_COUNTRY MILLIONS_EUROS EXPOSURE_COUNTRY  \
# 0       309,900.90      Austria       9,150.23          Austria
# 1       376,840.00      Austria          92.73          Belgium
# 2        39,667.70      Austria           1.76         Bulgaria
# 3        17,886.80      Austria           0.00           Cyprus
# 4       152,828.00      Austria       9,659.61   Czech Republic
# 5       244,063.70      Austria           0.02          Denmark
# 6        16,998.20      Austria           0.00          Estonia
# 7       194,469.00      Austria          78.68          Finland
# 8     2,029,877.40      Austria         106.22           France
# 9     2,643,900.00      Austria         883.61          Germany
# 10      193,749.00      Austria           0.76           Greece
# 11       97,756.30      Austria       1,618.29          Hungary
# 12       10,627.50      Austria           0.00          Iceland
# 13      163,595.40      Austria          38.93          Ireland
# 14    1,565,916.10      Austria          79.96            Italy
# 15       22,258.00      Austria           4.78           Latvia
# 16        3,860.50      Austria           0.00    Liechtenstein
# 17       32,781.80      Austria           6.95        Lithuania
# 18       44,218.80      Austria          22.56       Luxembourg
# 19        6,755.90      Austria           0.73            Malta
# 20      601,086.00      Austria          62.85      Netherlands
# 21      390,008.70      Austria           8.48           Norway
# 22      381,361.40      Austria         667.40           Poland
# 23      165,386.60      Austria           3.22         Portugal
# 24      131,739.60      Austria       3,976.74          Romania
# 25       71,463.00      Austria       5,473.68         Slovakia
# 26       35,466.30      Austria         383.17         Slovenia
# 27    1,048,490.60      Austria          45.38            Spain
# 28      408,467.20      Austria           4.33           Sweden
# 29    1,898,520.10      Austria           1.44   United Kingdom
# ...            ...          ...            ...              ...
# 1861    376,840.00     Slovenia          34.00          Belgium
# 1862     39,667.70     Slovenia           0.00         Bulgaria
# 1863     17,886.80     Slovenia           0.00           Cyprus
# 1864    152,828.00     Slovenia           0.00   Czech Republic
# 1865    244,063.70     Slovenia           0.00          Denmark
# 1866     16,998.20     Slovenia           0.00          Estonia
# 1867    194,469.00     Slovenia           0.00          Finland
# 1868  2,029,877.40     Slovenia           5.00           France
# 1869  2,643,900.00     Slovenia          10.00          Germany
# 1870    193,749.00     Slovenia           0.00           Greece
# 1871     97,756.30     Slovenia           0.00          Hungary
# 1872     10,627.50     Slovenia           0.00          Iceland
# 1873    163,595.40     Slovenia           0.00          Ireland
# 1874  1,565,916.10     Slovenia           0.00            Italy
# 1875     22,258.00     Slovenia           0.00           Latvia
# 1876      3,860.50     Slovenia           0.00    Liechtenstein
# 1877     32,781.80     Slovenia           0.00        Lithuania
# 1878     44,218.80     Slovenia           0.00       Luxembourg
# 1879      6,755.90     Slovenia           0.00            Malta
# 1880    601,086.00     Slovenia          11.00      Netherlands
# 1881    390,008.70     Slovenia           0.00           Norway
# 1882    381,361.40     Slovenia           0.00           Poland
# 1883    165,386.60     Slovenia           0.00         Portugal
# 1884    131,739.60     Slovenia           0.00          Romania
# 1885     71,463.00     Slovenia           2.00         Slovakia
# 1886     35,466.30     Slovenia         620.00         Slovenia
# 1887  1,048,490.60     Slovenia           0.00            Spain
# 1888    408,467.20     Slovenia           0.00           Sweden
# 1889  1,898,520.10     Slovenia           0.00   United Kingdom
# 1890                   Slovenia         710.00     TOTAL EEA 30
#
#      COUNTRY_EXPOSURE                                          BANK
# 0               28.27                           Erste Group Bank AG
# 1                0.29                           Erste Group Bank AG
# 2                0.01                           Erste Group Bank AG
# 3                0.00                           Erste Group Bank AG
# 4               29.84                           Erste Group Bank AG
# 5                0.00                           Erste Group Bank AG
# 6                0.00                           Erste Group Bank AG
# 7                0.24                           Erste Group Bank AG
# 8                0.33                           Erste Group Bank AG
# 9                2.73                           Erste Group Bank AG
# 10               0.00                           Erste Group Bank AG
# 11               5.00                           Erste Group Bank AG
# 12               0.00                           Erste Group Bank AG
# 13               0.12                           Erste Group Bank AG
# 14               0.25                           Erste Group Bank AG
# 15               0.01                           Erste Group Bank AG
# 16               0.00                           Erste Group Bank AG
# 17               0.02                           Erste Group Bank AG
# 18               0.07                           Erste Group Bank AG
# 19               0.00                           Erste Group Bank AG
# 20               0.19                           Erste Group Bank AG
# 21               0.03                           Erste Group Bank AG
# 22               2.06                           Erste Group Bank AG
# 23               0.01                           Erste Group Bank AG
# 24              12.28                           Erste Group Bank AG
# 25              16.91                           Erste Group Bank AG
# 26               1.18                           Erste Group Bank AG
# 27               0.14                           Erste Group Bank AG
# 28               0.01                           Erste Group Bank AG
# 29               0.00                           Erste Group Bank AG
# ...               ...                                           ...
# 1861             4.79  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1862             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1863             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1864             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1865             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1866             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1867             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1868             0.70  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1869             1.41  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1870             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1871             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1872             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1873             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1874             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1875             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1876             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1877             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1878             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1879             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1880             1.55  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1881             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1882             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1883             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1884             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1885             0.28  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1886            87.32  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1887             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1888             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1889             0.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
# 1890           100.00  NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)
#
# [1891 rows x 6 columns]

# %%
data.columns = ['gdp','origin','millions','exposure','perc','bank']  # rinomino le colonne
rearrange_columns = ['bank','origin','exposure','gdp','millions','perc']
data = data[rearrange_columns]
data.head()

# ho tutta la info di 61 json diversi in un'unica tabella
# Out:
#                   bank   origin        exposure         gdp  millions   perc
# 0  Erste Group Bank AG  Austria         Austria  309,900.90  9,150.23  28.27
# 1  Erste Group Bank AG  Austria         Belgium  376,840.00     92.73   0.29
# 2  Erste Group Bank AG  Austria        Bulgaria   39,667.70      1.76   0.01
# 3  Erste Group Bank AG  Austria          Cyprus   17,886.80      0.00   0.00
# 4  Erste Group Bank AG  Austria  Czech Republic  152,828.00  9,659.61  29.84

# %% [markdown]
# # Data Cleaning

# %%
#EX_2: poke around (rovistare) - any data cleaning?

# totale di ogni country da togliere (ogni banca somma quindi 200%)

# per ogni banca ho una exposure per ogni nazione, anche se quella nazione non ha exposure vs alcune nazioni: 
# elimino le righe che hanno millions zero (quelle righe mi danno connessioni nulle)

# le cifre hanno sia virgola che punti, tiro giù come stringhe, ma se le passo a numeri danno problemi; 
# elimino le righe 



#get rid (liberarsi) of null lines
data = data[data['millions']!='0.00']
# quando millions è diverso da zero, se uso la maschera, mi rimane la riga in cui millions è zero

#get rid of intermediate totals!
data = data[data['exposure']!='TOTAL EEA 30']
# tolgo i TOTAL EEA


#get rid of pesky (fastidiosi) commas in numbers
data['gdp'] = data['gdp'].astype('str').apply(lambda x : x.replace(',','')).astype('float')
data['millions'] = data['millions'].astype('str').apply(lambda x : x.replace(',','')).astype('float')

# tolgo le virgole: prendo il gdp, lo passo a una stringa, nella lambda elimina le virgole 
# sostituisci le virgole con niente, riportalo a numero (tramite float)

# %%
data
# Out:
#                                               bank    origin        exposure  \
# 0                              Erste Group Bank AG   Austria         Austria
# 1                              Erste Group Bank AG   Austria         Belgium
# 2                              Erste Group Bank AG   Austria        Bulgaria
# 4                              Erste Group Bank AG   Austria  Czech Republic
# 5                              Erste Group Bank AG   Austria         Denmark
# 7                              Erste Group Bank AG   Austria         Finland
# 8                              Erste Group Bank AG   Austria          France
# 9                              Erste Group Bank AG   Austria         Germany
# 10                             Erste Group Bank AG   Austria          Greece
# 11                             Erste Group Bank AG   Austria         Hungary
# 13                             Erste Group Bank AG   Austria         Ireland
# 14                             Erste Group Bank AG   Austria           Italy
# 15                             Erste Group Bank AG   Austria          Latvia
# 17                             Erste Group Bank AG   Austria       Lithuania
# 18                             Erste Group Bank AG   Austria      Luxembourg
# 19                             Erste Group Bank AG   Austria           Malta
# 20                             Erste Group Bank AG   Austria     Netherlands
# 21                             Erste Group Bank AG   Austria          Norway
# 22                             Erste Group Bank AG   Austria          Poland
# 23                             Erste Group Bank AG   Austria        Portugal
# 24                             Erste Group Bank AG   Austria         Romania
# 25                             Erste Group Bank AG   Austria        Slovakia
# 26                             Erste Group Bank AG   Austria        Slovenia
# 27                             Erste Group Bank AG   Austria           Spain
# 28                             Erste Group Bank AG   Austria          Sweden
# 29                             Erste Group Bank AG   Austria  United Kingdom
# 31            Raiffeisen Zentralbank Österreich AG   Austria         Austria
# 32            Raiffeisen Zentralbank Österreich AG   Austria         Belgium
# 33            Raiffeisen Zentralbank Österreich AG   Austria        Bulgaria
# 35            Raiffeisen Zentralbank Österreich AG   Austria  Czech Republic
# ...                                            ...       ...             ...
# 1795               Svenska Handelsbanken AB (publ)    Sweden          Sweden
# 1804                            Swedbank AB (publ)    Sweden         Estonia
# 1806                            Swedbank AB (publ)    Sweden          France
# 1807                            Swedbank AB (publ)    Sweden         Germany
# 1813                            Swedbank AB (publ)    Sweden          Latvia
# 1815                            Swedbank AB (publ)    Sweden       Lithuania
# 1816                            Swedbank AB (publ)    Sweden      Luxembourg
# 1819                            Swedbank AB (publ)    Sweden          Norway
# 1826                            Swedbank AB (publ)    Sweden          Sweden
# 1829        NOVA LJUBLJANSKA BANKA D.D. (NLB d.d.)  Sloven
# 2                    Erste Group Bank AG  Austria        Bulgaria    39667.7
# 4                    Erste Group Bank AG  Austria  Czech Republic   152828.0
# 5                    Erste Group Bank AG  Austria         Denmark   244063.7
# 7                    Erste Group Bank AG  Austria         Finland   194469.0
# 8                    Erste Group Bank AG  Austria          France  2029877.4
# 9                    Erste Group Bank AG  Austria         Germany  2643900.0
# 10                   Erste Group Bank AG  Austria          Greece   193749.0
# 11                   Erste Group Bank AG  Austria         Hungary    97756.3
# 13                   Erste Group Bank AG  Austria         Ireland   163595.4
# 14                   Erste Group Bank AG  Austria           Italy  1565916.1
# 15                   Erste Group Bank AG  Austria          Latvia    22258.0
# 17                   Erste Group Bank AG  Austria       Lithuania    32781.8
# 18                   Erste Group Bank AG  Austria      Luxembourg    44218.8
# 19                   Erste Group Bank AG  Austria           Malta     6755.9
# 20                   Erste Group Bank AG  Austria     Netherlands   601086.0
# 21                   Erste Group Bank AG  Austria          Norway   390008.7
# 22                   Erste Group Bank AG  Austria          Poland   381361.4
# 23                   Erste Group Bank AG  Austria        Portugal   165386.6
# 24                   Erste Group Bank AG  Austria         Romania   131739.6
# 25                   Erste Group Bank AG  Austria        Slovakia    71463.0
# 26                   Erste Group Bank AG  Austria        Slovenia    35466.3
# 27                   Erste Group Bank AG  Austria           Spain  1048490.6
# 28                   Erste Group Bank AG  Austria          Sweden   408467.2
# 29                   Erste Group Bank AG  Austria  United Kingdom  1898520.1
# 31  Raiffeisen Zentralbank Österreich AG  Austria         Austria   309900.9
# 32  Raiffeisen Zentralbank Österreich AG  Austria         Belgium   376840.0
# 33  Raiffeisen Zentralbank Österreich AG  Austria        Bulgaria    39667.7
# 35  Raiffeisen Zentralbank Österreich AG  Austria  Czech Republic   152828.0
#
#     millions   perc
# 0    9150.23  28.27
# 1      92.73   0.29
# 2       1.76   0.01
# 4    9659.61  29.84
# 5       0.02   0.00
# 7      78.68   0.24
# 8     106.22   0.33
# 9     883.61   2.73
# 10      0.76   0.00
# 11   1618.29   5.00
# 13     38.93   0.12
# 14     79.96   0.25
# 15      4.78   0.01
# 17      6.95   0.02
# 18     22.56   0.07
# 19      0.73   0.00
# 20     62.85   0.19
# 21      8.48   0.03
# 22    667.40   2.06
# 23      3.22   0.01
# 24   3976.74  12.28
# 25   5473.68  16.91
# 26    383.17   1.18
# 27     45.38   0.14
# 28      4.33   0.01
# 29      1.44   0.00
# 31    931.71  12.08
# 32     16.32   0.21
# 33    324.11   4.20
# 35    989.83  12.84

# %% [markdown]
# # Make DataFrames

# %%
#data:all, nndata:nation->nation, bdata:bipartite

# %%
print len(data)
data.head()
# Out:
# 859
#                   bank   origin        exposure       gdp  millions   perc
# 0  Erste Group Bank AG  Austria         Austria  309900.9   9150.23  28.27
# 1  Erste Group Bank AG  Austria         Belgium  376840.0     92.73   0.29
# 2  Erste Group Bank AG  Austria        Bulgaria   39667.7      1.76   0.01
# 4  Erste Group Bank AG  Austria  Czech Republic  152828.0   9659.61  29.84
# 5  Erste Group Bank AG  Austria         Denmark  244063.7      0.02   0.00

# %%
nndata = pd.DataFrame(data.groupby(['origin','exposure'], as_index=False)['millions'].sum()) 
# credito totale di una nazione vs un'altra nazione (sommo con group by)
print len(nndata)
nndata.head()
# nn: nation-nation: collegamenti tra nazioni
# alcune nazioni sono molto connesse, altre meno
# Out:
# 347
#     origin        exposure  millions
# 0  Austria         Austria  10081.94
# 1  Austria         Belgium    109.05
# 2  Austria        Bulgaria    325.87
# 3  Austria  Czech Republic  10649.44
# 4  Austria         Denmark      0.02

# %%
bdata = data[['bank','exposure','millions']]
print len(bdata)
bdata.head()
# connessioni tra banche e nazioni
# Out:
# 859
#                   bank        exposure  millions
# 0  Erste Group Bank AG         Austria   9150.23
# 1  Erste Group Bank AG         Belgium     92.73
# 2  Erste Group Bank AG        Bulgaria      1.76
# 4  Erste Group Bank AG  Czech Republic   9659.61
# 5  Erste Group Bank AG         Denmark      0.02

# %%
data['millions'].describe()
# Out:
# count      859.000000
# mean      2080.842829
# std       6654.755940
# min          0.010000
# 25%         21.000000
# 50%        128.890000
# 75%        743.820000
# max      71443.000000
# Name: millions, dtype: float64

# %% [markdown]
# # Adjacency Matrices (nndata and bdata)

# %%
nations = sorted(pd.concat([data.origin, data.exposure]).unique())
banks = sorted(data.bank.unique())
print len(nations),'nations,',len(banks),'banks'
# Out:
# 30 nations, 61 banks

# %%
print nations
# Out:
# [u'Austria', u'Belgium', u'Bulgaria', u'Cyprus', u'Czech Republic', u'Denmark', u'Estonia', u'Finland', u'France', u'Germany', u'Greece', u'Hungary', u'Iceland', u'Ireland', u'Italy', u'Latvia', u'Liechtenstein', u'Lithuania', u'Luxembourg', u'Malta', u'Netherlands', u'Norway', u'Poland', u'Portugal', u'Romania', u'Slovakia', u'Slovenia', u'Spain', u'Sweden', u'United Kingdom']

# %%
# calcolo le matrici di adiacenza
# serve per capire quanto è pesante una connessione 

adjm_w_nn = np.zeros([len(nations),len(nations)])
adjm_b_nn = np.zeros([len(nations),len(nations)])
for i,ie in enumerate(nations):
    for j,je in enumerate(nations):
        if ie in np.array(nndata['origin']) and je in np.array(nndata[nndata['origin']==ie]['exposure']):
            adjm_w_nn[i,j]=nndata[(nndata['origin']==ie) & (nndata['exposure']==je)]['millions']
            adjm_b_nn[i,j]=1
           
figure(figsize=(5,5))
pcolormesh(adjm_b_nn, cmap=cm.binary)

# es: una banca della nazione 3 possiede debito della nazione 25
# alcune righe sono vuote: ci sono nazioni che hanno un sacco di debito e altre che non ne hanno nessuno

# %%
# matrice di adiacenza binaria

adjm_w_b = np.zeros([len(banks),len(nations)])
adjm_b_b = np.zeros([len(banks),len(nations)])
for i,ie in enumerate(banks):
    for j,je in enumerate(nations):
        if ie in np.array(bdata['bank']) and je in np.array(bdata[bdata['bank']==ie]['exposure']):
            adjm_w_b[i,j]=bdata[(bdata['bank']==ie) & (bdata['exposure']==je)]['millions']
            adjm_b_b[i,j]=1

figure(figsize=(5,10))
pcolormesh(adjm_b_b, cmap=cm.binary)
plt.axis([0, len(nations), 0, len(banks)])

# stiamo guardando le matrici di adiacenza in ordine alfabetico, che è molto arbitrario
# Out:
# [0, 30, 0, 61]

# %%
#order is arbitrary

# %% [markdown]
# # Graph-Viz, part 1

# %%
#building graph, edge by edge
Gnn = nx.Graph()
for i in range(adjm_b_nn.shape[0]):
    for j in range(adjm_b_nn.shape[1]):
        if adjm_b_nn[i,j]==1:
            Gnn.add_edge(nations[i],nations[j])  # ho costruito il grapho a mano
figure(figsize=(10,10))
nx.draw(Gnn,with_labels=True)

# le lunghezze degli archi non sono significative
#

# %%
#the easy way
Gnn = nx.from_numpy_matrix(adjm_b_nn)   # così invece il grapho è costruito non in modo manuale
figure(figsize=(10,10))

nx.draw(Gnn,with_labels=True)

# ci sono numeri, perchè la matrice di adiacenza sono numeri, non ci sono piu le label
# i due graphi sono identici, la disposizione non è rilevante
# la posizione dei nodi non è determinante
# se ho nodi molto connessi, li mette in mezzo, altrimenti sono sparati in periferia

# %%
#and a bipartite graph

#building
from scipy.sparse import csr_matrix
from networkx.algorithms import bipartite
sparse_adj_matrix_b = csr_matrix(adjm_b_b)
Gb = bipartite.from_biadjacency_matrix(sparse_adj_matrix_b)

#drawing
figure(figsize=(5,15))
X, Y = bipartite.sets(Gb)
pos = dict()
pos.update((n, (0, i*10)) for i, n in enumerate(X))
pos.update((n, (0.5, i*10)) for i, n in enumerate(Y))
nx.draw(Gb, pos=pos)
plt.show()

# sinistra 60 banche, destra 30 nazioni

# %%
#Awful, right? Visualisation is not necessarily enlightning 
#We'll see something nicer further on. For now we'll use the graphs to compute metrics

# %% [markdown]
# # Metrics

# %%
#EX_3: Matrics! What can you obtain by groupby? What by using nx methods? How can you viz the results?

# %%
#out-degree (nation-clustered)
for name,group in nndata.groupby('origin'): # raggruppo per nazione di origine
    print name,len(group.groupby('exposure')), 

    # ho il grado uscente di ogni nazione: 27 connessioni uscenti dall'Austria
# Out:
# Austria 27 Belgium 22 Cyprus 13 Denmark 20 Finland 9 France 27 Germany 29 Hungary 4 Ireland 13 Italy 27 Luxembourg 15 Malta 16 Netherlands 25 Norway 7 Poland 1 Portugal 13 Slovenia 14 Spain 15 Sweden 22 United Kingdom 28

# %%
#in-degree (nation-clustered)
for name,group in nndata.groupby('exposure'):
    print name,len(group.groupby('origin')),
    

# non tutte le nazioni sono rappresentate da banche, per es non ci sono banche della Bulgaria, grado uscente 0
# però la Bulgaria ha 9 debiti verso 9 nazioni (9 connessioni entranti)
# Out:
# Austria 15 Belgium 16 Bulgaria 9 Cyprus 7 Czech Republic 11 Denmark 13 Estonia 4 Finland 14 France 17 Germany 18 Greece 14 Hungary 15 Iceland 5 Ireland 14 Italy 17 Latvia 10 Liechtenstein 1 Lithuania 10 Luxembourg 10 Malta 5 Netherlands 15 Norway 9 Poland 18 Portugal 13 Romania 10 Slovakia 12 Slovenia 9 Spain 12 Sweden 13 United Kingdom 11

# %%
#out-degree (bipartite)
for name,group in bdata.groupby('bank'):
    print name,len(group.groupby('exposure')),
# Out:
# ABN AMRO BANK NV 11 ALLIED IRISH BANKS PLC 12 BANCA MONTE DEI PASCHI DI SIENA S.p.A 16 BANCO BILBAO VIZCAYA ARGENTARIA S.A. (BBV
degrees_nn = (adjm_b_nn.sum(axis=1)+adjm_b_nn.sum(axis=0)-np.diagonal(adjm_b_nn)).astype('int')
print zip(nations,degrees_nn)
plot(sorted(degrees_nn), 'bx')
xlabel('list of nations')
ylabel('degree')

# zip: prende due liste e le associa, come una cerniera

# se sommo per riga, ho il grado uscente di una nazione
# somma per colonna: grado entrante di una nazione
# sommo per riga e per colonna, devo togliere la diagonale per non contare due volte,
# la diagonale la tolgo solo una volta (per non contarla),
# non la tolgo due volte perchè una nazione potrebbe avere del debito con se stessa

# 1: Liechestain
# Out:
# [(u'Austria', 41), (u'Belgium', 37), (u'Bulgaria', 9), (u'Cyprus', 19), (u'Czech Republic', 11), (u'Denmark', 32), (u'Estonia', 4), (u'Finland', 22), (u'France', 43), (u'Germany', 46), (u'Greece', 14), (u'Hungary', 18), (u'Iceland', 5), (u'Ireland', 26), (u'Italy', 43), (u'Latvia', 10), (u'Liechtenstein', 1), (u'Lithuania', 10), (u'Luxembourg', 24), (u'Malta', 20), (u'Netherlands', 39), (u'Norway', 15), (u'Poland', 18), (u'Portugal', 25), (u'Romania', 10), (u'Slovakia', 12), (u'Slovenia', 22), (u'Spain', 26), (u'Sweden', 34), (u'United Kingdom', 38)]

# %%
plt.hist(degrees_nn)
xlabel('degree')
ylabel('count')

# guardo per ogni valore quanti nodi ho con quel degree
# ho tanti nodi con degree da 10 a 15

# %%
np.array(sorted(degrees_nn))
# Out:
# array([ 1,  4,  5,  9, 10, 10, 10, 11, 12, 14, 15, 18, 18, 19, 20, 22, 22,
#        24, 25, 26, 26, 32, 34, 37, 38, 39, 41, 43, 43, 46])

# %%
#banks out_degree in bipartite graph
degrees_b_banks = sorted(adjm_b_b.sum(axis=1).astype('int'))
print degrees_b_banks
plot(degrees_b_banks, 'bx')
xlabel('list of banks')
ylabel('degree')
# Out:
# [1, 2, 2, 3, 3, 3, 4, 4, 4, 6, 6, 6, 7, 7, 7, 7, 8, 9, 10, 10, 10, 10, 11, 11, 11, 12, 12, 13, 13, 14, 15, 15, 15, 16, 16, 16, 17, 17, 17, 17, 17, 17, 18, 19, 19, 19, 19, 22, 22, 22, 23, 23, 24, 24, 25, 26, 26, 26, 26, 27, 28]

# %%
plt.hist(degrees_b_banks)
xlabel('degree')
ylabel('count')

# %%
#nations in_degree in bipartite graph
degrees_b_nations = sorted(adjm_b_b.sum(axis=0).astype('int'))
print degrees_b_nations
plot(degrees_b_nations, 'bx')
xlabel('list of nations')
ylabel('degree')
# Out:
# [1, 6, 6, 8, 14, 15, 17, 23, 23, 24, 25, 25, 26, 27, 28, 28, 29, 32, 34, 34, 35, 36, 39, 41, 43, 45, 46, 48, 50, 51]

# %%
plt.hist(degrees_b_nations)
xlabel('degree')
ylabel('count')

# %%
nu_order = argsort(degrees_nn)
sorted_adjm_b_nn = np.copy(adjm_b_nn)
sorted_adjm_b_nn = sorted_adjm_b_nn[nu_order,:]
sorted_adjm_b_nn = sorted_adjm_b_nn[:,nu_order]
figure(figsize=(5,5))
pcolormesh(sorted_adjm_b_nn, cmap=cm.binary)

# %%
#now we finally use the graphs
nn_betweenness = nx.betweenness_centrality(Gnn)
print nn_betweenness
plot(sorted(nn_betweenness.values()))
xlabel('list of nations')
ylabel('betweenness')

# ci sono diverse nazioni con betweeness trascurabili e poche nazioni con betweeness alta
# Out:
# {0: 0.09789155152455646, 1: 0.018515659217629665, 2: 0.0, 3: 0.004599444069887419, 4: 0.0011846117757447808, 5: 0.018556682780820715, 6: 0.0, 7: 0.011048256614759078, 8: 0.04469831618846397, 9: 0.06460800420160026, 10: 0.0022733150811968545, 11: 0.0073877613902244435, 12: 0.0, 13: 0.0033944845521200195, 14: 0.06460800420160026, 15: 0.0007215007215007215, 16: 0.0, 17: 0.0008835991594612285, 18: 0.006417563006232958, 19: 0.005942422383309083, 20: 0.028006059348423887, 21: 0.0017788724685276409, 22: 0.005477117299777399, 23: 0.00488937034503537, 24: 0.0011053806620309084, 25: 0.0009862879321007399, 26: 0.004361224435116061, 27: 0.0034451317702549234, 28: 0.032816629183624255, 29: 0.04469831618846397}

# %%
#let's have a closer look
sorted([(v,nations[k]) for k,v in nx.betweenness_centrality(Gnn).items()]) [::-1] #-1 va all'indietro
# va dal più alto al più basso
# ordina le grandezze di prima per centrality

# sorted([(v,nations[k]) for k,v in nx.betweenness_centrality(Gnn).items()])
# così parte dalle piu basse
# Out:
# [(0.09789155152455646, u'Austria'),
#  (0.06460800420160026, u'Italy'),
#  (0.06460800420160026, u'Germany'),
#  (0.04469831618846397, u'United Kingdom'),
#  (0.04469831618846397, u'France'),
#  (0.032816629183624255, u'Sweden'),
#  (0.028006059348423887, u'Netherlands'),
#  (0.018556682780820715, u'Denmark'),
#  (0.018515659217629665, u'Belgium'),
#  (0.011048256614759078, u'Finland'),
#  (0.0073877613902244435, u'Hungary'),
#  (0.006417563006232958, u'Luxembourg'),
#  (0.005942422383309083, u'Malta'),
#  (0.005477117299777399, u'Poland'),
#  (0.00488937034503537, u'Portugal'),
#  (0.004599444069887419, u'Cyprus'),
#  (0.004361224435116061, u'Slovenia'),
#  (0.0034451317702549234, u'Spain'),
#  (0.0033944845521200195, u'Ireland'),
#  (0.0022733150811968545, u'Greece'),
#  (0.0017788724685276409, u'Norway'),
#  (0.0011846117757447808, u'Czech Republic'),
#  (0.0011053806620309084, u'Romania'),
#  (0.0009862879321007399, u'Slovakia'),
#  (0.0008835991594612285, u'Lithuania'),
#  (0.0007215007215007215, u'Latvia'),
#  (0.0, u'Liechtenstein'),
#  (0.0, u'Iceland'),
#  (0.0, u'Estonia'),
#  (0.0, u'Bulgaria')]

# %%
plt.hist(nn_betweenness.values())
xlabel('betweenness')
ylabel('count')

# ho 20 nazioni su 30 poco rilevanti; ciò è dovuto al fatto che il grapho è molto connesso 
# (se tolgo quella nazione, il grapho non è connesso)

# %%
#Scatterplots!

# %%
nation_agg = pd.DataFrame()
nation_agg['name'] = nations
nation_agg['nn_degree'] = degrees_nn
nation_agg['nn_indegree'] = adjm_b_nn.sum(axis=0).astype('int')
nation_agg['nn_outdegree'] = adjm_b_nn.sum(axis=1).astype('int')
nation_agg['bank_indegree'] = adjm_b_b.sum(axis=0).astype('int')
nation_agg['debt'] = np.array(data.groupby('exposure')['millions'].apply(sum))
nation_agg['betweenness'] = nn_betweenness.values()
nation_agg
# Out:
#               name  nn_degree  nn_indegree  nn_outdegree  bank_indegree  \
# 0          Austria         41           15            27             41
# 1          Belgium         37           16            22             46
# 2         Bulgaria          9            9             0             14
# 3           Cyprus         19            7            13             15
# 4   Czech Republic         11           11             0             27
# 5          Denmark         32           13            20             25
# 6          Estonia          4            4             0              8
# 7          Finland         22           14             9             36
# 8           France         43           17            27             48
# 9          Germany         46           18            29             51
# 10          Greece         14           14             0             28
# 11         Hungary         18           15             4             34
# 12         Iceland          5            5             0              6
# 13         Ireland         26           14            13             35
# 14           Italy         43           17            27             50
# 15          Latvia         10           10             0             25
# 16   Liechtenstein          1            1             0              1
# 17       Lithuania         10           10             0             26
# 18      Luxembourg         24           10            15             24
# 19           Malta         20            5            16              6
# 20     Netherlands         39           15            25             43
# 21          Norway         15            9             7             17
# 22          Poland         18           18             1             45
# 23        Portugal         25           13            13             34
# 24         Romania         10           10             0             23
# 25        Slovakia         12           12             0             28
# 26        Slovenia         22            9            14             23
# 27           Spain         26           12            15             39
# 28          Sweden         34           13            22             32
# 29  United Kingdom         38           11            28             29
#
#          debt  betweenness
# 0    42815.13     0.097892
# 1    89978.57     0.018516
# 2     1162.29     0.000000
# 3     3135.22     0.004599
# 4    28598.32     0.001185
# 5    33095.21     0.018557
# 6      789.84     0.000000
# 7    15310.45     0.011048
# 8   192219.82     0.044698
# 9   469335.47     0.064608
# 10    1947.67     0.002273
# 11   18687.96     0.007388
# 12      42.01     0.000000
# 13   18134.24     0.003394
# 14  279816.58     0.064608
# 15     967.28     0.000722
# 16       0.09     0.000000
# 17    2450.70     0.000884
# 18    4585.03     0.006418
# 19    2374.11     0.005942
# 20   95330.58     0.028006
# 21   13356.50     0.001779
# 22   40251.91     0.005477
# 23   36033.44     0.004889
# 24    8919.60     0.001105
# 25   14307.70     0.000986
# 26    5720.01     0.004361
# 27  187751.49     0.003445
# 28   25669.18     0.032817
# 29  154657.59     0.044698

# %%
banks_agg = pd.DataFrame()
banks_agg['name'] = banks
banks_agg['degree'] = adjm_b_b.sum(axis=1).astype('int')
banks_agg['owned_debt'] = np.array(data.groupby('bank')['millions'].apply(sum))
banks_agg
# Out:
#                                                  name  degree  owned_debt
# 0                                    ABN AMRO BANK NV      11    18737.00
# 1                              ALLIED IRISH BANKS PLC      12     7943.93
# 2               BANCA MONTE DEI PASCHI DI SIENA S.p.A      16    30671.93
# 3         BANCO BILBAO VIZCAYA ARGENTARIA S.A. (BBVA)      15    61496.44
# 4   BANCO COMERCIAL PORTUGUÊS, SA (BCP OR MILLENNI...      10     6081.78
# 5                               BANCO POPOLARE - S.C.       2    15590.00
# 6                         BANCO POPULAR ESPAÑOL, S.A.       3    15600.19
# 7                                BANCO SANTANDER S.A.      11    71769.61
# 8                        BANK OF CYPRUS PUBLIC CO LTD      12     1933.23
# 9                                     BANK OF IRELAND       6     6458.00
# 10                             BANK OF VALLETTA (BOV)      16     1681.86
# 11               BANQUE ET CAISSE D'EPARGNE DE L'ETAT      15     4164.58
# 12                                       BARCLAYS plc      26    81596.46
# 13                                        BNP PARIBAS      27    90164.37
# 14                                               BPCE      22    71802.54
# 15                                      Banco BPI, SA       4     6914.43
# 16                              Bayerische Landesbank      17    41352.31
# 17                       CAIXA GERAL DE DEPÓSITOS, SA      10     8676.98
# 18           CAJA DE AHORROS Y PENSIONES DE BARCELONA       6    28301.27
# 19                                     COMMERZBANK AG      26    55087.75
# 20                                    CREDIT AGRICOLE      17    55558.44
# 21                  CYPRUS POPULAR BANK PUBLIC CO LTD       7     2810.76
# 22                                        DANSKE BANK      17    19000.37
# 23                                   DEUTSCHE BANK AG      28    58970.56
# 24         DZ BANK AG Dt. Zentral-Genossenschaftsbank      23    37373.88
# 25          DekaBank Deutsche Girozentrale, Frankfurt      10    17313.00
# 26                                   DnB NOR Bank ASA       7    10586.73
# 27          ESPÍRITO SANTO FINANCIAL GROUP, SA (ESFG)       3     5157.93
# 28                                Erste Group Bank AG      26    32372.51
# 29                                  HSBC HOLDINGS plc      24    77231.00
# ..                                                ...     ...         ...
# 31               Hypo Real Estate Holding AG, München      19    38200.00
# 32                                        ING BANK NV      25    67512.31
# 33                              INTESA SANPAOLO S.p.A      22    78906.00
# 34                           IRISH LIFE AND PERMANENT       3     2725.39
# 35                                         Jyske Bank      13      922.45
# 36                                           KBC BANK      22    45395.38
# 37                           LLOYDS BANKING GROUP plc       7    35281.35
# 38                       Landesbank Baden-Württemberg      19    51575.00
# 39                               Landesbank Berlin AG      17    17606.80
# 40          Landesbank Hessen-Thüringen GZ, Frankfurt      17    25816.63
# 41       NOVA KREDITNA BANKA MARIBOR D.D. (NKBM d.d.)       7      710.00
# 42             NOVA LJUBLJANSKA BANKA D.D. (NLB d.d.)      14     1821.11
# 43                        Norddeutsche Landesbank -GZ      19    49786.81
# 44                              Nordea Bank AB (publ)      18    36353.53
# 45                                           Nykredit       6     2833.00
# 46                                   OP-Pohjola Group       9     1261.52
# 47                                     OTP BANK NYRT.       4     3284.64
# 48  POWSZECHNA KASA OSZCZ?DNO?CI BANK POLSKI S.A. ...       1     5117.62
# 49                                 RABOBANK NEDERLAND      15    37699.92
# 50                   ROYAL BANK OF SCOTLAND GROUP plc      23    72761.22
# 51               Raiffeisen Zentralbank Österreich AG      19     7710.67
# 52                                        SNS BANK NV      10    11865.00
# 53                                   SOCIETE GENERALE      24    52586.38
# 54      Skandinaviska Enskilda Banken AB (publ) (SEB)      17    31188.66
# 55                    Svenska Handelsbanken AB (publ)      11     5735.00
# 56                                 Swedbank AB (publ)       8     4883.71
# 57                                            Sydbank       2      289.00
# 58                                    UNICREDIT S.p.A      26    96148.30
# 59         UNIONE DI BANCHE ITALIANE SCPA (UBI BANCA)       4    18988.13
# 60           WGZ BANK AG Westdt. Geno. Zentralbk, Ddf      16    25748.71
#
# [61 rows x 3 columns]

# %%
def scatterplot(x,y,l):   # metodo scatter
    figure(figsize=(10,10))
    plt.scatter(x,y)
    for i,label in enumerate(l):
        plt.text(x[i],y[i],label)

# %%
scatterplot(adjm_w_nn.sum(axis=1),adjm_w_nn.sum(axis=0),nations)

# %%
banks_agg.head()
# Out:
#                                                 name  degree  owned_debt
# 0                                   ABN AMRO BANK NV      11    18737.00
# 1                             ALLIED IRISH BANKS PLC      12     7943.93
# 2              BANCA MONTE DEI PASCHI DI SIENA S.p.A      16    30671.93
# 3        BANCO BILBAO VIZCAYA ARGENTARIA S.A. (BBVA)      15    61496.44
# 4  BANCO COMERCIAL PORTUGUÊS, SA (BCP OR MILLENNI...      10     6081.78

# %%
scatterplot(banks_agg['degree'],banks_agg['owned_debt'],banks)
xlabel('degree')
ylabel('owned_debt')

# %%
nation_agg.head()
# Out:
#              name  nn_degree  nn_indegree  nn_outdegree  bank_indegree  \
# 0         Austria         41           15            27             41
# 1         Belgium         37           16            22             46
# 2        Bulgaria          9            9             0             14
# 3          Cyprus         19            7            13             15
# 4  Czech Republic         11           11             0             27
#
#        debt  betweenness
# 0  42815.13     0.097892
# 1  89978.57     0.018516
# 2   1162.29     0.000000
# 3   3135.22     0.004599
# 4  28598.32     0.001185

# %%
scatterplot(nation_agg['debt'],nation_agg['bank_indegree'],nations) 
# x: debito, y:banche che possiedono quel debito

xlabel('debt')
ylabel('bank_indegree')

# più a destra e in basso: poche connessioni e pesanti

# %% [markdown]
# # Community Detection

# %%
import community
c = community.best_partition(Gnn)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-95-b2c3c846d2b8> in <module>()
# ----> 1 import community
#       2 c = community.best_partition(Gnn)
#
# ImportError: No module named community

# %%
['red','blue']

# %%
import community
c = community.best_partition(Gnn)
colors = ['red','blue','green','cyan']
nx.draw(Gnn,
        pos=nx.fruchterman_reingold_layout(Gnn), 
        cmap=plt.cm.hsv,
        node_color=[colors[i] for i in [c[node] for node in Gnn.nodes()]])

# %%
clustered_nations = [n for (v,n) in sorted([(v,nations[k]) for (k,v) in c.items()])]
nu_order = argsort(argsort(clustered_nations))
sorted_adjm_b_nn = np.copy(adjm_b_nn)
sorted_adjm_b_nn = sorted_adjm_b_nn[nu_order,:]
sorted_adjm_b_nn = sorted_adjm_b_nn[:,nu_order]
figure(figsize=(5,5))
pcolormesh(sorted_adjm_b_nn, cmap=cm.binary)

# %% [markdown]
# # Graph-Viz, part 2

# %%
G_nn_exp = nx.DiGraph()
for i in range(adjm_w_nn.shape[0]):
    for j in range(adjm_w_nn.shape[1]):
        if adjm_w_nn[i,j]>0:
            #print nations[i],nations[j],adjm_w_nn[i,j]
            G_nn_exp.add_edge(nations[i],nations[j],weight=adjm_w_nn[i,j])
nx.write_gml(G_nn_exp,'graph_nn.gml') # crea in output questo file

G_b_exp = nx.DiGraph()
for k in banks:
    G_b_exp.add_node(k,bipartite='bank')
for k in nations:
    G_b_exp.add_node(k,bipartite='nation')
for i in range(adjm_w_b.shape[0]):
    for j in range(adjm_w_b.shape[1]):
        if adjm_w_b[i,j]>0:
            #print banks[i],nations[j],adjm_w_b[i,j]
            G_b_exp.add_edge(banks[i],nations[j],weight=adjm_w_b[i,j])
nx.write_gml(G_b_exp,'graph_b_bip.gml')

# %%
#to gephi!
